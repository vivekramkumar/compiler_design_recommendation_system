# %% [markdown]
# # CS6109 - Compiler Design Project
#
# **Project Topic: Social Recommendations with multiple influence from Direct User Interactions**
#
# Done by:
#
#     Vivek Ramkumar, 2018103082
#     Kariketi Tharun Reddy, 201803034
#     G. R. Srikanth, 2018103603
#
#     Third Years studying B.E, Computer Science, at College of Engineering, Guindy
#     Chennai, Tamil Nadu, India

# %% [markdown]
# # Importing Standard Libraries:

# %%
import numpy as np
import pandas as pd 
from collections import OrderedDict
import gc
import random

import os

# %% [markdown]
# # Obtaining Data:

# %% [markdown]
# We are using three datasets of products, from which recommendations will be made.
#
# 1. Groceries Dataset
# 2. Flipkart Product Database
# 3. Consumer Reviews of Amazon Products
#
# While extracting data from the respective databases, we need to ensure there are no duplicate items or NaN values.
#
# So, we use OrderedDict.fromkeys() to remove all duplicate items. We then check whether any NaN values exist
# in the list of products. If there are NaN values, we promptly exclude them.
#
# Finally, we delete the database as it occupies a lot of space in the RAM.
# gc.collect() is a garbage collection function used to clear up any extra leftovers from the deletion.
#
# This process is repeated for all the three databases.

# %%
groceries_db = pd.read_csv('groceries - groceries.csv')

new_groceries_db = groceries_db.drop(columns = ['Item(s)'])

temp = []

for i in range(len(new_groceries_db.columns)):
    for x in new_groceries_db.iloc[:, i]:
        temp.append(x)
            
groceries = [] 

groceries = list(OrderedDict.fromkeys(temp))

groceries = [item for item in groceries if str(item) != 'nan']

del groceries_db, new_groceries_db
gc.collect()
# Out:
# 0

# %%
flipkart_db = pd.read_csv('flipkart_com-ecommerce_sample.csv')

temp = flipkart_db['product_name']

flipkart_items = [] 

flipkart_items = list(OrderedDict.fromkeys(temp))

flipkart_items = [item for item in flipkart_items if str(item) != 'nan']

del flipkart_db
gc.collect()
# Out:
# 0

# %%
def read_amzn_prod_dbs(file_path):
    
    temp_db = pd.read_csv(file_path)

    temp = temp_db['name']
    
    return temp
    
def append_list_to_list(orig_list, new_list):
    
    for x in orig_list:
        new_list.append(x)

temp_1 = read_amzn_prod_dbs('1429_1.csv')
temp_2 = read_amzn_prod_dbs('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')
temp_3 = read_amzn_prod_dbs('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')

temp = []

append_list_to_list(temp_1, temp)
append_list_to_list(temp_2, temp)
append_list_to_list(temp_3, temp)

amazon_items = [] 

amazon_items = list(OrderedDict.fromkeys(temp))

amazon_items = [item for item in amazon_items if str(item) != 'nan']
# Out:
# C:\Users\crack\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:2818: DtypeWarning: Columns (1,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# We combine all the obtained lists of products into a singular mega-list.
#
# This list will be referred to for recommending products to the users.

# %%
complete_list = []

append_list_to_list(flipkart_items, complete_list)
append_list_to_list(groceries, complete_list)
append_list_to_list(amazon_items, complete_list)

# %%
print("The total number of products available to recommend :", len(complete_list))
# Out:
# The total number of products available to recommend : 12970

# %% [markdown]
# **The mega-list contains over 12,000 product names. This is a sizeable amount, enough to get different recommendations on every run.**

# %% [markdown]
# # Lexical Analysis:

# %% [markdown]
# The main focus of lexical analysis is to obtain tokens from the given text input.
#
# We need to differentiate between entities (users, organizations, religion, etc.) and interests (garments, tech, etc.).
#
# The technique we are going to employ is called POS tagging. (POS -> Part of Speech)
#
# POS tagging algorithms allocate tags to each token, such as "NOUN", "VERB", "ADJ", etc., based on the similarity to their respective tagged categories.
#
# We will be using the Spacy library, which contains pre-trained NLP models and a huge dictionary of words.
#
# The input is parsed sentence by sentence, from which nouns, verbs, users, and user types are obtained. The respective information is summarized in a pandas dataframe. You will see it in the 'Input and Output' section.

# %%
import nltk
import spacy

from spacy import displacy

from nltk.corpus import stopwords

nltk.download('stopwords')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\crack\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def tokenizer(text, nouns, verbs, users, user_types):
    
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    
    for token in doc:
        if token.pos_ == 'NOUN':
            nouns.append(str(token))

        if token.pos_ == 'VERB':
            verbs.append(str(token))

    for entity in doc.ents:
        users.append(entity.text)
        user_types.append(entity.label_)
    
    nouns = [word for word in nouns if not word in stopwords.words()]

# %% [markdown]
# Keep in mind the input is made to understand short conversations - especially one-liners.
#
# Basically, we separate the text blob by the '\n', or newline symbol.
# This is done by using the splitlines() function.
#
# If any respective dialogue consists of two lines, the parser will be confused and allocate an extra user to the extra line.
#
# This is done with consideration to social messaging applications, as users frequently communicate with short dialogues.

# %%
def get_tokens(text):
    
    conversation = text.splitlines()

    token_summary = pd.DataFrame({'Users': [], 'Nouns': [], 'Verbs': [], 'User_Types': []})

    for dialogue in conversation:
    
        nouns = []
        verbs = []
        users = []
        user_types = []

        tokenizer(dialogue, nouns, verbs, users, user_types)
    
        nouns = list(OrderedDict.fromkeys(nouns))
        verbs = list(OrderedDict.fromkeys(verbs))
    
        token_summary = token_summary.append({'Users': users, 'Nouns': nouns, 'Verbs': verbs, 'User_Types': user_types}, ignore_index=True)
    
    return conversation, token_summary

# %% [markdown]
# # Syntax Analysis:

# %% [markdown]
# The main point of understanding the syntax of the sentence is to check the order by which tokens are parsed.
#
# For example, seeing a "not" before a verb, say "enjoying", can imply a negative sentiment.
#
# Sentiment analysis is an important tool in recommendation - it helps recommend products to those who want it.
#
# People who express negative sentiment towards a product will not recieve recommendations on it.
#
# Instead, they will get recommendations based on what their friends like.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

def get_sentiments(conversation):

    sentiments = pd.DataFrame({'Dialogue': [], 'Compound': [], 'Negative': [], 'Neutral': [], 'Positive': []})

    sid = SentimentIntensityAnalyzer()

    for dialogue in conversation:
    
        ss = sid.polarity_scores(dialogue)
    
        sentiments = sentiments.append({'Dialogue': dialogue, 'Compound': ss['compound'], 'Negative': ss['neg'], 'Neutral': ss['neu'], 'Positive': ss['pos']}, ignore_index = True)
        
    return sentiments
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\crack\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# The NTLK Vader Sentiment Analyzer is an excellent tool for quickly analyzing the sentiment of a sentence.
#
# We will obtain the polarity scores in each sentiment category, i.e "Positive", "Negative", "Neutral", and "Compound", for each user.
#
# A summary of the sentiments expressed by each user will be shown in the 'Input and Output' section.

# %%
def display_dependency_tree(conversation):

    nlp = spacy.load("en_core_web_sm")

    for dialogue in conversation:
    
        doc = nlp(dialogue)

        displacy.render(doc, style="dep")

# %% [markdown]
# The Spacy library consists of one more feature - the ability to show dependency trees.
#
# Dependency trees are useful in understanding the parsing process, in pursuit of finding the sentiments.
#
# You can see the respective dependency trees for each user in the "Input and Output" section.

# %% [markdown]
# # Recommendation(Semantic):

# %% [markdown]
# This is the recommendation section.
#
# We will check the list of nouns from our summary of tokens to see what the interests of the users are.
#
# If the particular noun is present in any product name, we will store that product name in a new list.
#
# This new list is considered as our initial set of recommendations.

# %%
def create_init_rec(token_summary):

    rec_1 = []

    for i in range(len(token_summary['Nouns'])):
    
        sublist = []
    
        for x in token_summary['Nouns'][i]:
        
            for y in complete_list:
            
                if x.lower() in y.lower():
                    sublist.append(y)
        
        rec_1.append(sublist)
        
    return rec_1

# %% [markdown]
# Now, our initial recommendations are quite a large number.
#
# We will pick five products at random, to recommend to each user.
#
# Of course, we do not want to get the same products again in our random selection.
#
# This is easily achieved by using random.sample(list, k), where k is the number of items selected. This function also ensures that there is no repetition in the selection of items.

# %%
def get_actual_rec(rec_1):

    recommendations = []

    for i in range(len(rec_1)):
    
        sublist = random.sample(rec_1[i], 5)
    
        recommendations.append(sublist)
        
    return recommendations

# %%
def mixed_rec(rec, index):
    
    temp = []
    
    for i in range(len(rec)):
        
        if(i==index):
            if(i == len(rec)-1):
                temp.append(random.choice(rec[i-1]))
            else:
                temp.append(random.choice(rec[i+1]))
        else:
            temp.append(random.choice(rec[i]))
        
    return temp

# %% [markdown]
# As stated before, the sentiment of the user is considered as a factor in the recommendation process.
#
# The compounded polarity score is considered here.
#
# If a user's sentiment is negative, then we pick a random recommendation based on the interests of that user's friends.
#
# Otherwise, if it is positive or neutral, we can directly recommend based on their individual interest.

# %%
def print_rec():

    print("Recommendations are: \n")

    i = 0

    for u in token_summary['Users']:
            
        for x in u:
            
            if(sentiments['Compound'][i] > 0):     
                print(x, '->', recommendations[i])
            elif(sentiments['Compound'][i] < 0):
                print(x, '->', mixed_rec(recommendations, i))
            else:
                print(x, '->', recommendations[i])
        
            print()
            i = i + 1

# %% [markdown]
# # Input and Output

# %% [markdown]
# **This is the input text.**
#
# **Every time you want to get some new recommendations, tweak this and run the cells below it.**

# %%
text = """ Rahul : I like to play on my tablet.
 Gokul : My dog does not enjoy using dog shampoo.
 Ankita : I love to wear a kurta.
 Badrinath : I frequently wear a shirt.
 Vijay : I am searching for a nice watch. 
 Srikanth : I like to play cricket."""

# %%
conversation, token_summary = get_tokens(text)

# %%
token_summary
# Out:
#          Users           Nouns           Verbs User_Types
# 0      [Rahul]        [tablet]    [like, play]   [PERSON]
# 1      [Gokul]  [dog, shampoo]  [enjoy, using]   [PERSON]
# 2     [Ankita]         [kurta]    [love, wear]   [PERSON]
# 3  [Badrinath]         [shirt]          [wear]   [PERSON]
# 4      [Vijay]         [watch]     [searching]   [PERSON]
# 5   [Srikanth]       [cricket]    [like, play]   [PERSON]

# %%
sentiments = get_sentiments(conversation)

# %%
sentiments
# Out:
#                                             Dialogue  Compound  Negative  \
# 0               Rahul : I like to play on my tablet.    0.5994     0.000
# 1   Gokul : My dog does not enjoy using dog shampoo.   -0.3875     0.247
# 2                   Ankita : I love to wear a kurta.    0.6369     0.000
# 3             Badrinath : I frequently wear a shirt.    0.0000     0.000
# 4          Vijay : I am searching for a nice watch.     0.4215     0.000
# 5                 Srikanth : I like to play cricket.    0.5994     0.000
#
#    Neutral  Positive
# 0    0.505     0.495
# 1    0.753     0.000
# 2    0.488     0.512
# 3    1.000     0.000
# 4    0.641     0.359
# 5    0.380     0.620

# %% [markdown]
# Shown below are the dependency trees for each sentence.
#
# The arrows infer dependencies between words. If an arrow points from 'a' to 'b', then it can be understood that 'a' depends on 'b'.
#
# This is useful in seeing how the tokens are tagged, and how the sentence is syntactically analyzed.

# %%
display_dependency_tree(conversation)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d7a3adab5d3e43c4b88c813170c5f407-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Rahul :</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">play</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">tablet.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,179.0 L1103.0,167.0 1087.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-6" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,179.0 L1287,167.0 1303,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d7a3adab5d3e43c4b88c813170c5f407-0-7" stroke-width="2px" d="M1120,177.0 C1120,2.0 1450.0,2.0 1450.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d7a3adab5d3e43c4b88c813170c5f407-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,179.0 L1458.0,167.0 1442.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7c4fa644b8c1482aa2bf713c179f647b-0" class="displacy" width="1800" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Gokul :</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">enjoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">shampoo.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-1" stroke-width="2px" d="M245,352.0 C245,2.0 1100.0,2.0 1100.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-3" stroke-width="2px" d="M595,352.0 C595,89.5 1095.0,89.5 1095.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-4" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">neg</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-6" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1260.0,354.0 L1268.0,342.0 1252.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-7" stroke-width="2px" d="M1470,352.0 C1470,264.5 1610.0,264.5 1610.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,354.0 L1462,342.0 1478,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c4fa644b8c1482aa2bf713c179f647b-0-8" stroke-width="2px" d="M1295,352.0 C1295,177.0 1615.0,177.0 1615.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c4fa644b8c1482aa2bf713c179f647b-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1615.0,354.0 L1623.0,342.0 16
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b074e1f298a74b6baa6f67805cf8ac0c-0" class="displacy" width="1450" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Ankita :</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">love</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">wear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">kurta.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-5" stroke-width="2px" d="M1120,177.0 C1120,89.5 1270.0,89.5 1270.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,179.0 L1112,167.0 1128,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-6" stroke-width="2px" d="M945,177.0 C945,2.0 1275.0,2.0 1275.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b074e1f298a74b6baa6f67805cf8ac0c-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1275.0,179.0 L1283.0,167.0 1267.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ab22584323a0436cba7a0aebf22d85b8-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Badrinath :</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">frequently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">wear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">shirt.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab22584323a0436cba7a0aebf22d85b8-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab22584323a0436cba7a0aebf22d85b8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab22584323a0436cba7a0aebf22d85b8-0-1" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab22584323a0436cba7a0aebf22d85b8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab22584323a0436cba7a0aebf22d85b8-0-2" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab22584323a0436cba7a0aebf22d85b8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab22584323a0436cba7a0aebf22d85b8-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab22584323a0436cba7a0aebf22d85b8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab22584323a0436cba7a0aebf22d85b8-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab22584323a0436cba7a0aebf22d85b8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ab22584323a0436cba7a0aebf22d85b8-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ab22584323a0436cba7a0aebf22d85b8-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e5c9d0dce2764370bb6060ce251420d7-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Vijay :</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">searching</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">nice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">watch.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-1" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-2" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e5c9d0dce2764370bb6060ce251420d7-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e5c9d0dce2764370bb6060ce251420d7-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4256a5d4b39c4714bed7b521195ba7f7-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Srikanth :</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">play</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">cricket.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4256a5d4b39c4714bed7b521195ba7f7-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4256a5d4b39c4714bed7b521195ba7f7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4256a5d4b39c4714bed7b521195ba7f7-0-1" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4256a5d4b39c4714bed7b521195ba7f7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4256a5d4b39c4714bed7b521195ba7f7-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4256a5d4b39c4714bed7b521195ba7f7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4256a5d4b39c4714bed7b521195ba7f7-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4256a5d4b39c4714bed7b521195ba7f7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4256a5d4b39c4714bed7b521195ba7f7-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4256a5d4b39c4714bed7b521195ba7f7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4256a5d4b39c4714bed7b521195ba7f7-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4256a5d4b39c4714bed7b521195ba7f7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,179.0 L1103.0,167.0 1087.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# This is the initial list of recommendations.
#
# We will be picking random items, based on the user's interests, to recommend each user.

# %%
rec_1 = create_init_rec(token_summary)
rec_1
# Out:
# [['cm key 354 Wired USB Tablet Keyboard',
#   'Shortkut enterprises Model no 400 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 456 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 428 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 483 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 476 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 477 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 497 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 460 Mobile/Tablet Speaker',
#   'Shortkut enterprises Model no 434 Mobile/Tablet Speaker',
#   'couponsmall key 343 Wired USB Tablet Keyboard',
#   "Orientel Universal 360' Rotation Rubber Suction Cup Car Mount Stand Holder ABS Colorful For Tablet PC & Mobile Phone",
#   'i-Static Universal Car Tablet Holder',
#   'Autosun OK Stand Smartphone & Tablet Stand',
#   'Smartpro 10.5v,2.9a for Tablet Charger 75 Adapter',
#   'Generix pack of 5 Micro USB On-the-go For Mobile Phones & Tablets OTG Cable',
#   'Generix Pack of 2 Micro USB On-the-go For Mobile Phones & Tablets OTG Cable',
#   'BEcom Sleeve for ALL 14.5 inch Tablet iPad Tab Funbook Playbook',
#   'Saco Karbonn Smart Ta Fone A37 Hd Tablet Wired USB Tablet Keyboard',
#   'Kanu Flip Cover for Micromax Funbook P255 Tablet',
#   'Fastway Book Cover for Micromax Canvas Tab P690 8GB 3G Calling Tablet',
#   'APS Sleeve for iBall Slide 7334q Tablet',
#   'BILLYS Cases with Holder for All 7 Inch Tab/Tablet 360° Rotating',
#   'Fastway Book Cover for Wespro 7 Inch Capacitiv Tablet',
#   'APS Sleeve for Datawind Ubislate 10Ci Tablet',
#   'APS Sleeve for Vox V105 Calling Tablet',
#   'iCare Flip Cover for Universal Rotate 7 inch Tablet',
#   'Unique Designes Flip Cover for domo x3G tablet (7inch)',
#   'Cotab R2 \xa0360 Degree rotatable Ring stand holder for all smartphones , Tablets & iPhones Mobile Holder Mobile Holder',
#   'Shortkut enterprises 510 Mobile/Tablet Speaker',
#   'Corcepts Universal Tablet HD Ultra Clear Transparency Guard Glass for 8" Tablet spg8105 Tempered Glass for Dell Venue 8 Tablet (WiFi+3G+32GB)',
#   'Corcepts Universal Tablet HD Ultra Clear Transparency Guard Glass for 8" Tablet spg8126 Tempered Glass for Lenovo Miix 2 10OUT OF STOCK',
#   'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta',
#   'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Magenta',
#   'Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Tangerine - with Special Offers,',
#   'Amazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,\r\nAmazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,',
#   'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Magenta',
#   'Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black,,,\r\nFire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers",',
#   'Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers,',
#   'Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,',
#   'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Green Kid-Proof Case',
#   'Amazon Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Blue Kid-Proof Case - Blue',
#   'Amazon Fire Hd 8 8in Tablet 16gb Black B018szt3bk 6th Gen (2016) Android,,,\r\nAmazon Fire Hd 8 8in Tablet 16gb Black B018szt3bk 6th Gen (2016) Android,,,',
#   'Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black',
#   'Echo (White),,,\r\nFire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Tangerine"',
#   'Echo (Black),,,\r\nAmazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,',
#   'Amazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,\r\nAmazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,',
#   'Amazon Fire Hd 6 Standing Protective Case(4th Generation - 2014 Release), Cayenne Red,,,\r\nAmazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,',
#   'Amazon Fire Hd 10 Tablet, Wi-Fi, 16 Gb, Special Offers - Silver Aluminum,,,\r\nAmazon Fire Hd 10 Tablet, Wi-Fi, 16 Gb, Special Offers - Silver Aluminum,,,',
#   'Amazon Kindle Fire 5ft USB to Micro-USB Cable (works with most Micro-USB Tablets),,,\r\nAmazon Kindle Fire 5ft USB to Micro-USB Cable (works with most Micro-USB Tablets),,,',
#   'Amazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fire Tablets and Kindle eReaders',
#   'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Blue Kid-Proof Case',
#   'Fire Tablet, 7 Display, Wi-Fi, 16 GB - Includes Special Offers, Black',
#   'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Blue',
#   'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Blue',
#   'Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Silver Aluminum',
#   'All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta',
#   'Brand New Amazon Kindle Fire 16gb 7" Ips Display Tablet Wifi 16 Gb Blue',
#   'Fire HD 8 Tablet with Alexa, 8" HD Display, 32 GB, Tangerine - with Special Offers',
#   'All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi, 32 GB - Includes Special Offers, Black',
#   'All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi, 32 GB - Includes Special Offers, Magenta',
#   'Fire Tablet with Alexa, 7" Display, 16 GB, Magenta - with Special Offers',
#   'AmazonBasics 15.6-Inch Laptop and Tablet Bag',
#   'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Black',
#   'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-Proof Case',
#   'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Black',
#   'All-New Fire 7 Tablet with Alexa, 7" Display, 8 GB - Marine Blue',
#   'Amazon Fire HD 8 with Alexa (8" HD Display Tablet)',
#   'All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Pink Kid-Proof Case',
#   'All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Blue Kid-Proof Case',
#   'All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Marine Blue - with Special Offers',
#   'All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Marine Blue - with Special Offers',
#   'Fire Tablet with Alexa, 7 Display, 16 GB, Magenta - with Special Offers',
#   'Fire Tablet with Alexa, 7 Display, 16 GB, Blue - with Special Offers',
#   'Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Tangerine - with Special Offers',
#   'Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers'],
#  ['Sicons All Purpose Arnica Dog Shampoo',
#   'Sicons All Purpose Tea Tree Dog Shampoo',
#   'Sicons Conditioning Conditoner Dog Shampoo',
#   'Kennel Rubber Dumbell With Bell - Small Rubber Rubber Toy For Dog',
#   'Snug Hug Jute Chew Toy For Dog',
#   'Pawzone Rubber Rubber Toy For Dog',
#   'Rockmantra Dog Ceramic Mug',
#   'Four Paws Sweats for Cat, Dog',
#   'Edit One Romance Dog Cartoon Art Plastic Pencil Box',
#   'Magideal Raincoat for Dog',
#   'Petto Raincoat for Dog, Cat',
#   'Speedwav Car Loud Hooter Dog -Mitsubishi Outlander 200 dB Vehicle Horn',
#   'Speedwav Car Loud Hooter Dog -Nissan Micra 200 dB Vehicle Horn',
#   'Speedwav Bike Loud Hooter Dog -Hero Hunk 200 dB Vehicle Horn',
#   'Speedwav Car / Bike Loud Hooter Dog Horn-Hyundai Xcent 110 dB Vehicle Horn',
#   'Royal Canin Maxi Starter 1kg Vegetable Dog Food',
#   'Babyoye Premium Dog Face Bib',
#   "Monica Dogra for Stylista Women's Dress",
#   'dog food',
#   'Two Door Top Load Pet Kennel Travel Crate Dog Cat Pet Cage Carrier Box Tray 23"',
#   'AmazonBasics Single-Door Folding Metal Dog Crate - Large (42x28x30 Inches)',
#   'AmazonBasics Double-Door Folding Metal Dog Crate - Medium (36x23x25 Inches)',
#   'Sicons All Purpose Arnica Dog Shampoo',
#   'Sicons All Purpose Tea Tree Dog Shampoo',
#   'Sicons Conditioning Conditoner Dog Shampoo',
#   'Brillare Science Dandruff Control Shampoo & Intenso Creme Combo',
#   'Park Avenue Oily Beer Shampoo Combo Set',
#   'Oxyglow Golden Glow Pearl Protein Shampoo & Fruit Massage Cream With Vitamin-E 200gm',
#   'TRESemme Naturals Vibrantly Smooth Shampoo',
#   'L Oreal Eversleek Sulfate - Free Smoothing System Intense Smoothing Shampoo',
#   'Kerastase Nutritive Bain Satin 1 Complete Nutrition Shampoo'],
#  ["Vishudh Printed Women's Straight Kurta",
#   "Vishudh Printed Women's Anarkali Kurta",
#   "MASARA Solid Women's Straight Kurta",
#   "Noor Embroidered Women's Straight Kurta",
#   "Libas Printed Women's A-line Kurta",
#   "Libas Printed Women's Anarkali Kurta",
#   "Love More Printed Women's Anarkali Kurta",
#   "Love More Printed Women's Straight Kurta",
#   "Royal Men's Kurta and Pyjama Set",
#   "CORA Striped Girl's Straight Kurta",
#   "Alark The Ethnic Men's Kurta and Pyjama Set",
#   "RETAIL SHOP INDIA Printed Girl's Straight Kurta",
#   "Love More Printed Women's Flared Kurta",
#   'Saarah Self Design Kurta & Churidar',
#   'Salwar Studio Geometric Print, Paisley Kurta & Salwar',
#   'Salwar Studio Self Design Kurta & Salwar',
#   'F-Loop Self Design Kurta & Churidar',
#   "Aarika Girl's Kurta and Pallazo Set",
#   "Swag India Girl's Kurta and Pallazo Set",
#   "Retaaz Girl's Kurta and Leggings Set",
#   "Aarika Girl's Kurta and Churidar Set",
#   "Jazzup Boy's Kurta and Pyjama Set",
#   "Embellish outfits Embroidered Women's Straight Kurta",
#   "ADDICTION Floral Print Women's Straight Kurta",
#   "Embellish outfits Graphic Print Women's Straight Kurta",
#   "Fab Nisa Self Design Women's Straight Kurta",
#   "Fab Nisa Solid Women's Straight Kurta",
#   'gurjari oxidised kurta button brooch Brooch',
#   'gurjari oxidiesd kurta button brooch Brooch',
#   "Lil'Posh Baby Girl's Kurta and Churidar Set",
#   "RTD Baby Girl's Kurta and Pyjama Set",
#   "RTD Baby Girl's Kurta and Churidar Set",
#   "Parijat Embroidered Women's Straight Kurta",
#   "FS Mini Klub Solid Baby Boy's Pathani Kurta",
#   "FS Mini Klub Solid Boy's Pathani Kurta",
#   "Ratan Jaipur Checkered Women's Straight Kurta",
#   "AJ Dezines Boy's Kurta and Breeches Set",
#   "AJ Dezines Boy's Kurta, Waistcoat and Pyjama Set",
#   "Jbn Creation Boy's Kurta, Pyjama & Dupatta Set",
#   "Jazzup Baby Boy's Kurta and Pyjama Set",
#   "Kishore Dresses Boy's Kurta and Dhoti Pant Set",
#   "FTCBAZAR Boy's Kurta and Pyjama Set",
#   "FTCBazar Boy's Kurta and Dhoti Pant Set",
#   "Jeet Boy's Kurta and Pyjama Set",
#   "NIPPY Boy's Kurta, Waistcoat and Breeches Set",
#   'JDK NOVELTY Brocade, Art Silk, Organza Floral Print Multi-purpose Fabric, Kurti Fabric, Blouse Material, Kurta Fabric, Dress/Top Material, Jacket Fabric, Kurta & Pallazo Material, Sherwani Fabric, Kurta & Churidar Material, Lace, Salwar Suit Material, Kurta & Patiyala Material, Lehenga Choli Material',
#   'JDK NOVELTY Brocade, Art Silk, Organza Self Design Multi-purpose Fabric, Kurti Fabric, Blouse Material, Kurta Fabric, Dress/Top Material, Jacket Fabric, Kurta & Pallazo Material, Sherwani Fabric, Kurta & Churidar Material, Lace, Salwar Suit Material, Kurta & Patiyala Material, Lehenga Choli Material',
#   'JDK NOVELTY Brocade, Art Silk, Organza Floral Print Multi-purpose Fabric, Kurti Fabric, Blouse Material, Kurta Fabric, Dress/Top Material, Jacket Fabric, Lehenga Choli Material, Kurta & Patiyala Material, Salwar Suit Material, Lace, Kurta & Churidar Material, Sherwani Fabric, Kurta & Pallazo Material',
#   'JDK NOVELTY Brocade, Art Silk, Organza Floral Print Multi-purpose Fabric, Kurta & Pallazo Material, Kurti Fabric, Lace, Salwar Suit Material, Jacket Fabric, Kurta Fabric, Lehenga Choli Material, Blouse Material, Kurta & Churidar Material, Kurta & Patiyala Material, Dress/Top Material, Sherwani Fabric',
#   'JDK NOVELTY Brocade, Art Silk, Organza Floral Print Multi-purpose Fabric, Kurti Fabric, Blouse Material, Dress/Top Material, Jacket Fabric, Salwar Suit Material, Kurta & Pallazo Material, Lehenga Choli Material, Lace, Kurta Fabric, Kurta & Patiyala Material, Kurta & Churidar Material, Sherwani Fabric',
#   "RANGSUTRA Embroidered Women's A-line Kurta",
#   "Gulmohar Jaipur Embroidered Women's Straight Kurta",
#   "Baalaa Printed Women's Straight Kurta",
#   "Shwetna.com Checkered Women's Straight Kurta",
#   "Baalaa Striped Women's Straight Kurta",
#   "AaliyaB Embellished Women's Flared Kurta",
#   "Baalaa Solid Women's Flared Kurta",
#   "Gulmohar Jaipur Printed Women's Straight Kurta",
#   "Shwetna.com Embroidered Women's Straight Kurta",
#   "eStyle Solid Girl's A-line Kurta",
#   "BrandMeUp Solid Women's Straight Kurta",
#   "COTTON ON KIDS Printed Girl's Straight Kurta",
#   'stylishvilla Embroidered Kurta & Patiyala',
#   'stylishvilla Embroidered Kurta & Churidar',
#   'Khushi Fashions Printed Kurta & Pallazo',
#   "GO LUCKNOW Embroidered Women's Straight Kurta",
#   "Jbn Creation Boy's Kurta and Pyjama Set",
#   "Jaipurkurti Striped Women's Straight Kurta",
#   'Nut Khut Embroidered Kurta & Churidar',
#   'Aarika Self Design Kurta & Patiyala',
#   'Aarika Self Design Kurta & Pallazo',
#   'Saarah Self Design Kurta & Salwar',
#   "Royal Men's Kurta and Churidar Set",
#   'Arshia Fashions Printed Kurta & Leggings',
#   "AJ Dezines Boy's Kurta and Pyjama Set",
#   "FTCBAZAR Solid Men's Straight Kurta",
#   "FreeHand Solid Men's Straight Kurta",
#   "Yepme Embroidered Men's A-line Kurta",
#   "Royal Kurta Men's Pathani Suit Set",
#   "KA Women's Kurta, Pyjama & Dupatta Set",
#   "Lajo Women's Kurta, Pyjama & Dupatta Set",
#   "Cynthia's Fashion Women's, Girl's Kurta, Pyjama & Dupatta Set",
#   "Lajo Women's Salwar and Kurta Set",
#   "DEEPAK N DIVYA Women's Kurta and Pyjama Set"],
#  ["dongli Printed Boy's Round Neck T-Shirt",
#   "Mario Gotze Women's Printed Casual Orange Shirt",
#   "Discountgod Men's Checkered Casual Shirt",
#   "Silver Streak Men's Printed Casual Denim Shirt",
#   "Wake Up Competition Full Sleeve Striped Men's Sweatshirt",
#   "Van Heusen Men's Printed Party Shirt",
#   "Fashion Tree Men's Solid Formal Shirt",
#   "Peter England Men's Solid Formal Shirt",
#   "Lee Mark Men's Solid Formal Shirt",
#   "Status Quo Men's Solid Casual Shirt",
#   "Absurd Full Sleeve Solid Men's Sweatshirt",
#   "Absurd Full Sleeve Solid Men's Reversible Sweatshirt",
#   "Fundoo T Full Sleeve Solid Men's Sweatshirt",
#   "Wrangler Men's Casual Shirt",
#   "Rute Floral Print Women's Round Neck T-Shirt",
#   "Pulpypapaya Self Design Women's Round Neck T-Shirt",
#   "Parron Men's Solid Casual Shirt",
#   "Parron Men's Printed Casual Shirt",
#   "Komnil Solid Women's Polo T-Shirt",
#   "BURDY Graphic Print Men's Polo Neck Dark Blue T-Shirt",
#   "I Know Men's Solid Casual Dark Blue Shirt",
#   "Candy House Solid Men's Polo Neck T-Shirt",
#   "Raymond Men's Printed Formal Blue Shirt",
#   "Nike Graphic Print Boy's Round Neck White T-Shirt",
#   "Beebay Striped Boy's Polo Blue T-Shirt",
#   "YK Printed Boy's Round Neck Dark Blue T-Shirt",
#   "ferari Men's Solid Casual Yellow Shirt",
#   "CREEDS Men's Printed Casual Multicolor Shirt",
#   "Calvin Klein Men's Solid Casual White Shirt",
#   "YK Printed Girl's Round Neck White T-Shirt",
#   "appleofmyi Printed Girl's Round Neck Green T-Shirt",
#   "Ethna Women's Solid Casual Shirt",
#   "Famous by Payal Kapoor Women's Printed Casual Shirt",
#   "Glus Perfect Body Women's T-Shirt Bra",
#   "Ploomz Fashion Women's T-Shirt Bra",
#   "Younky Fashion Women's T-Shirt Bra",
#   "Status Fashionable Women's T-Shirt Bra",
#   "Ploomz Women's T-Shirt Bra",
#   "Scorpio Fashions Women's T-Shirt Bra",
#   "Status Push-Up Women's T-Shirt Bra",
#   "Tia by Ten on Ten Percy Women's T-Shirt Bra",
#   "ShowTime Women's Full Coverage, T-Shirt Bra",
#   "Tia by Ten on Ten Perla Women's T-Shirt Bra",
#   "Status Fashion Women's T-Shirt Bra",
#   "PrivateLifes MultiStraps Women's T-Shirt, Push-up Bra",
#   "Tia by Ten on Ten Princa Women's T-Shirt Bra",
#   "Tia by Ten on Ten Lizzy Women's T-Shirt Bra",
#   "PrettySecrets Yellow Cotton Comfort Women's T-Shirt Bra",
#   "Tia by Ten on Ten Vintage Women's T-Shirt Bra",
#   "Tia by Ten on Ten Bella Women's T-Shirt Bra",
#   "Glus Accu Point Women's T-Shirt Bra",
#   "Tia by Ten on Ten Penny Women's T-Shirt Bra",
#   "PrivateLifes Polka Lace Women's T-Shirt Bra",
#   "Glus Transy Back Women's T-Shirt Bra",
#   "Status T-Shirt Bra Women's Full Coverage Bra",
#   "Sherry by Sherry - 512 Women's T-Shirt Bra",
#   "Tia by Ten on Ten Cathy Women's T-Shirt Bra",
#   "Tia by Ten on Ten Siana Women's T-Shirt Bra",
#   "Soie Classic Women's T-Shirt Bra",
#   "Tia by Ten on Ten Fiona Women's T-Shirt Bra",
#   "Glus Angellove Women's T-Shirt Bra",
#   "Tia by Ten on Ten Persa Women's T-Shirt Bra",
#   "Tia by Ten on Ten Fanny Women's T-Shirt Bra",
#   "Hemali Pink Women's T-Shirt Bra",
#   'Penny T-Shirt Bra',
#   "Tia by Ten on Ten Stripey Women's T-Shirt Bra",
#   "PrettySecrets Women's T-Shirt, Push-up Bra",
#   "Tia by Ten on Ten Funky Women's T-Shirt Bra",
#   "Silver Streak Men's Printed Casual Shirt",
#   "Pepito Full Sleeve Printed Boy's Sweatshirt",
#   "Shaftesbury London Men's Solid Formal Shirt",
#   "Stylenara Men's Solid Casual Shirt",
#   "Shaftesbury London Men's Striped Formal Shirt",
#   "F Factor by Pantaloons Men's Solid Formal Shirt",
#   "Baaamboos Men's Solid Formal Shirt",
#   "Blackberrys Men's Solid Formal Shirt",
#   "Richworth Men's Solid Formal Shirt",
#   "Smugglerzinc Solid Men's Polo Neck T-Shirt",
#   "Scorpion Solid Men's Polo Neck T-Shirt",
#   "Villagsio Solid Men's Polo Neck T-Shirt",
#   "Vox Pop Printed Men's Round Neck T-Shirt",
#   "Baklol Printed Men's Round Neck T-Shirt",
#   "Puma Men's Striped Casual Shirt",
#   "SayItLoud Printed Men's Round Neck T-Shirt",
#   "Bralux Dolly Women's T-Shirt Bra",
#   "Black Wing Graphic Print Men's V-neck T-Shirt",
#   "baaamboos Men's Solid Formal Shirt",
#   "Bodyline Bossy Women's T-Shirt Bra",
#   "Whistle Solid Men's Round Neck T-Shirt",
#   "Da Intimo Seamless Women's T-Shirt Bra",
#   "Deep Under Maximum Women's Full Coverage, T-Shirt Bra",
#   "4thneed Solid Men's Polo T-Shirt",
#   "Planet Superheroes Graphic Print Men's V-neck T-Shirt",
#   "DNA Graphic Print Men's Round Neck T-Shirt",
#   "Rawpockets Graphic Print Men's Round Neck T-Shirt",
#   "Care N Care Labela Women's T-Shirt Bra",
#   "Maharaja Men's Solid Formal Shirt",
#   "Oxemberg Men's Solid Formal Shirt",
#   "SayItloud Printed Men's Round Neck T-Shirt",
#   "Nucode Striped Men's Polo Neck T-Shirt",
#   "D'INDIAN CLUB Men's Solid Formal Shirt",
#   "Spur Solid Men's Polo Neck T-Shirt",
#   "Care N Care Labela C Women's T-Shirt Bra",
#   "Bodyline Hosiery High-Touch Designed . Women's T-Shirt Bra",
#   "Calibra Women's Full Coverage, T-Shirt Bra",
#   "Calibra Regular Cup Bra Women's T-Shirt Bra",
#   "Clovia Cotton Rich T Shirt With Cross-Over Moulded Cups Women's Full Coverage Bra",
#   "Huetrap Graphic Print Men's Round Neck T-Shirt",
#   "Deep Under Little Heart Women's Full Coverage, T-Shirt Bra",
#   "LivUP Solid Men's Henley T-Shirt",
#   "Goodkarma Men's Self Design Casual Shirt",
#   "Marc N' Park Men's Solid Casual Shirt",
#   "Ebry Men's Checkered Casual Shirt",
#   "Goodkarma Men's Printed Casual Shirt",
#   "Marc N' Park Men's Printed Casual Shirt",
#   "Ebry Men's Printed Casual Shirt",
#   "Pavino Men's Solid Casual Shirt",
#   "Hoffmen Men's Self Design Formal Shirt",
#   "John Players Men's Checkered Formal Shirt",
#   'Cotts Hub Cotton Polyester Blend Solid Shirt Fabric',
#   "I-Voc Men's Printed Casual Shirt",
#   "Bleu Men's Solid Casual Shirt",
#   "Bleu Men's Checkered Casual Shirt",
#   "C9 Solid Women's Round Neck Pink T-Shirt",
#   "Go India Store Solid Women's Polo Neck Red, Black T-Shirt",
#   "PURYS Printed Women's Round Neck Pink T-Shirt",
#   "Well on Embroidered Men's Polo Neck T-Shirt",
#   "Weardo Solid Men's Polo Neck T-Shirt",
#   "White Kalia Printed Men's Round Neck T-Shirt",
#   "Wrogn Solid Men's V-neck T-Shirt",
#   "Be 13 Printed Baby Boy's Round Neck T-Shirt",
#   'United Colors of Benetton Printed Round Neck T-Shirt',
#   "GINI & JONY Solid Baby Boy's Round Neck T-Shirt",
#   "Nucode Graphic Print Men's Round Neck T-Shirt",
#   "Oviyon Solid Men's Polo Neck T-Shirt",
#   "Numero Uno Striped Men's Polo Neck T-Shirt",
#   "Nucode Solid Men's V-neck T-Shirt",
#   "Numero Uno Solid Men's V-neck T-Shirt",
#   "Numero Uno Solid Men's Round Neck T-Shirt",
#   "Oviyon Solid Men's Round Neck T-Shirt",
#   "Oviyon Printed Men's Round Neck T-Shirt",
#   "Orange and Orchid Solid Men's Polo T-Shirt",
#   "Nuteez Solid Men's Round Neck T-Shirt",
#   "Nitlon Solid Men's Henley, Round Neck T-Shirt",
#   "Okane Solid Men's Round Neck T-Shirt",
#   "Ninja Turtles Printed Men's Round Neck T-Shirt",
#   "Osho Fashion Concepts Printed Men's V-neck T-Shirt",
#   "Ninja Turtles Printed Men's Polo T-Shirt",
#   "Nirvana Printed Men's Round Neck T-Shirt",
#   "Numero Uno Printed Men's Polo Neck T-Shirt",
#   "Opiumstreet Printed Men's Round Neck T-Shirt",
#   "Oviyon Solid Men's V-neck T-Shirt",
#   "Okane Printed Men's Round Neck T-Shirt",
#   "Northern Lights Striped Men's V-neck T-Shirt",
#   "Nod'R Solid Men's Round Neck T-Shirt",
#   "Numero Uno Printed Men's Round Neck T-Shirt",
#   "Ocean 9 Striped Men's Polo T-Shirt",
#   "Nimya Solid Men's Polo Neck T-Shirt",
#   "Northern Lights Solid Men's Round Neck T-Shirt",
#   "Oviyon Printed Men's V-neck T-Shirt",
#   "Norwood Striped Men's Polo Neck T-Shirt",
#   "Origin Thai Solid Men's V-neck T-Shirt",
#   "Okane Striped Men's Polo Neck T-Shirt",
#   "Nivia Solid Men's Round Neck T-Shirt",
#   "OuttaSkin Striped Men's Polo Neck T-Shirt",
#   "Northern Lights Solid Men's Polo Neck T-Shirt",
#   "Ovl Graphic Print Men's Round Neck T-Shirt",
#   "Okane Solid Men's Polo T-Shirt",
#   "Onn Solid Men's Polo Neck T-Shirt",
#   "Orange and Orchid Striped Men's Polo T-Shirt",
#   "Numero Uno Printed Men's V-neck T-Shirt",
#   "Outtaskin Striped Men's Round Neck T-Shirt",
#   "Numero Uno Solid Men's Polo Neck T-Shirt",
#   "Numero Uno Solid Men's Polo T-Shirt",
#   "Origin Thai Printed Men's Round Neck T-Shirt",
#   "Osberry Solid Men's Henley T-Shirt",
#   "Orange Plum Printed Men's Round Neck T-Shirt",
#   "Ninja Turtle Printed Men's Polo T-Shirt",
#   "Ocean Race Graphic Print Men's Round Neck T-Shirt",
#   "Outtaskin Striped Men's Polo Neck T-Shirt",
#   "Ocean Race Solid Men's Round Neck T-Shirt",
#   "Northern Lights Striped Men's Round Neck T-Shirt",
#   "Nimbus Solid Men's Flap Collar Neck T-Shirt",
#   "Northern Lights Striped Men's Polo Neck T-Shirt",
#   "One For Blue Printed Men's Round Neck T-Shirt",
#   "Officers Choice Solid Men's Round Neck T-Shirt",
#   "Orange And Orchid Striped Men's Polo Neck T-Shirt",
#   "Numero Uno Striped Men's Polo T-Shirt",
#   "Numero Uno Solid Men's Henley T-Shirt",
#   "Ninja Turtle Printed Men's Round Neck T-Shirt",
#   "Osberry Printed Men's Round Neck T-Shirt",
#   "O And O Printed Men's Round Neck T-Shirt",
#   "Oharish Printed Men's Round Neck T-Shirt",
#   "Nucode Solid Men's Polo T-Shirt",
#   "Nod'R Solid Men's V-neck T-Shirt",
#   "Norwood Striped Men's Polo Neck Reversible T-Shirt",
#   "Orange and Orchid Printed Men's Round Neck T-Shirt",
#   "Onn Solid Men's Round Neck T-Shirt",
#   "Omtex Solid Men's Polo Neck T-Shirt",
#   "Ocean 9 Solid Men's Polo T-Shirt",
#   "Nuteez Printed Men's Round Neck T-Shirt",
#   "One For Blue Animal Print Men's Round Neck T-Shirt",
#   "Orange and Orchid Striped Men's V-neck T-Shirt",
#   "Nucode Solid Men's Polo Neck T-Shirt",
#   "Okane Solid Men's Polo Neck T-Shirt",
#   "Osho Fashion Concepts Printed Men's Round Neck T-Shirt",
#   "Nimbus Printed Men's Round Neck T-Shirt",
#   "Numero Uno Men's T-Shirt",
#   "Nord51 Solid Men's Polo Neck T-Shirt",
#   "NKM Solid Men's Polo Neck T-Shirt",
#   "Nord51 Solid Men's Polo T-Shirt",
#   "Numero Uno Striped Men's V-neck T-Shirt",
#   "Oviyon Embroidered Men's Polo Neck T-Shirt",
#   "Online Maniya Striped Men's Round Neck T-Shirt",
#   "Numalo Solid Men's Polo Neck T-Shirt",
#   "Nitlon Solid Men's Round Neck T-Shirt",
#   "Ocean 9 Self Design Men's Fashion Neck T-Shirt",
#   "Northern Lights Printed Men's Polo Neck T-Shirt",
#   "Nikolas Graphic Print Men's Round Neck T-Shirt",
#   "Ocean 9 Solid Men's Fashion Neck T-Shirt",
#   "Nivia Solid Men's Polo Neck T-Shirt",
#   "Outtaskin Solid Men's V-neck T-Shirt",
#   "Numalo Striped, Embroidered Men's Polo Neck T-Shirt",
#   "Orange and Orchid Solid, Printed Men's Round Neck T-Shirt",
#   "Nucode Graphic Print Men's V-neck T-Shirt",
#   "Nuteez Graphic Print Men's Round Neck T-Shirt",
#   "One11 Solid Men's, Women's Polo Neck T-Shirt",
#   "Origin Sport Solid Men's Polo T-Shirt",
#   "Okane Self Design Men's Polo Neck T-Shirt",
#   "Origin Sport Solid Men's V-neck T-Shirt",
#   "Northern Lights Printed Men's Round Neck T-Shirt",
#   "Online Maniya Solid Men's V-neck T-Shirt",
#   "Out of Print Printed Men's Round Neck T-Shirt",
#   "Origin Sport Solid Men's Round Neck T-Shirt",
#   "Osho Fashion Concepts Solid Men's V-neck T-Shirt",
#   "Nucode Geometric Print Men's Round Neck T-Shirt",
#   "Ocean Race Solid Men's V-neck T-Shirt",
#   "Ninja Turtle Men's T-Shirt",
#   "Online Maniya Self Design Men's Round Neck T-Shirt",
#   "Orange and Orchid Solid Men's Round Neck T-Shirt",
#   "Northern Lights Solid Men's V-neck T-Shirt",
#   "One For Blue Animal Print Women's Round Neck T-Shirt",
#   "1OAK Women's Floral Print Casual Shirt",
#   "1OAK Women's Polka Print Casual Shirt",
#   "KRAZY KATZ Solid Men's Round Neck T-Shirt",
#   "Provalley Printed Boy's Round Neck T-Shirt",
#   "Provalley Printed Boy's Polo Neck T-Shirt",
#   "Sathiyas Printed Boy's Round Neck T-Shirt",
#   "Gkidz Solid Boy's Polo Neck T-Shirt",
#   "Dongli Solid Boy's Round Neck T-Shirt",
#   "New Day Graphic Print Boy's Round Neck T-Shirt",
#   "Palm Tree Printed Boy's Round Neck T-Shirt",
#   "Goddess Women Women's Animal Print Casual Shirt",
#   "Mask Lifestyle Women's Animal Print Casual Shirt",
#   "Trend18 Women's Animal Print Casual Shirt",
#   "Love From India Women's Printed Casual Shirt",
#   "Yash Women's Animal Print Casual Shirt",
#   "The Beach Company Women's Animal Print Casual Shirt",
# ...
#   'Gift Island SW13392E Fashionin Digital Watch  - For Women',
#   'Times 333TMS333 Party-Wedding Analog Watch  - For Women',
#   'Times 119B0119 Sports Analog Watch  - For Boys',
#   'Sonata 7007YL07 Analog Watch  - For Men',
#   'Maxima 25703PPKW Fiber Analog Watch  - For Women',
#   'HMT B0445 Analog Watch  - For Women',
#   'HMT HMTWHQ Analog Watch  - For Men',
#   'Sonata 1141YM22 Analog Watch  - For Men',
#   'Timewel 1100-N1685 Analog Watch  - For Men',
#   'Maxima 05660PPGW Analog Watch  - For Men, Women',
#   'Maxima 13881PPGW FIBER COLLECTION Analog Watch  - For Men',
#   'Sonata 8925YM05 Analog Watch  - For Women',
#   'Sonata 7011SM05 Yuva Analog Watch  - For Men',
#   'Gift Island SW13676C Fashionin Digital Watch  - For Men',
#   'Maxima 24864LMGY Analog Watch  - For Men',
#   'Maxima 10310LMGI Attivo Analog Watch  - For Men',
#   'Maxima 23237PPGN FIBER COLLECTION Analog Watch  - For Men',
#   'Maxima 22024CMLY Gold Analog Watch  - For Women',
#   'Times 280TMS280 Party-Wedding Analog Watch  - For Women',
#   'Maxima 04608CMGY Gold Analog Watch  - For Men',
#   'Maxima 01784BMLY Gold Analog Watch  - For Women',
#   'Only Kidz 20581 Barbie Digital Watch  - For Women',
#   'Sonata 7092SL01 Yuva Analog Watch  - For Men',
#   "Stol'n KIDS-TIME01-1 Tweety Analog Watch  - For Girls, Boys",
#   'Sonata 7036YL02 Watch',
#   'Maxima 15812BMLY Gold Analog Watch  - For Women',
#   'Sonata 7924SL03 Sport Casual Analog Watch  - For Men',
#   'Maxima 26512PPGN FIBER COLLECTION Analog Watch  - For Men',
#   'Maxima 20681LPLI Swarovski Analog Watch  - For Women',
#   'Sonata 7970SL05 Watch',
#   'Times 367TMS367 Party-Wedding Analog Watch  - For Women',
#   'Times 109B0109 Sports Analog Watch  - For Boys',
#   'Maxima 01427CMGY Gold Analog Watch  - For Men',
#   'Maxima 20020LMGI Attivo Analog Watch  - For Men',
#   'Flippd FD040195 Casual Analog Watch  - For Women, Girls',
#   'Petrol PCWBL68 Analog Watch  - For Men',
#   'Flippd FDRBB1814 Fibre Analog Watch  - For Men',
#   'Sonata 7958PP01 Analog Watch',
#   'Timewel 1100-N144 Analog Watch  - For Men',
#   'Gift Island SW13389C Fashionin Digital Watch  - For Men',
#   'Flippd FD040103 Formal Analog Watch  - For Men, Boys',
#   'Maxima 01741LPLN Analog Watch  - For Women',
#   'Omax KD109 Analog Watch  - For Boys, Girls',
#   'Times 269TMS269 Party-Wedding Analog Watch  - For Men',
#   'Sonata 7052YM07 Watch',
#   'Maxima 20141CMGI Attivo Analog Watch  - For Men',
#   'Only Kidz 20238 Barbie Analog Watch  - For Boys, Girls',
#   'Petrol PMW93W2 Analog Watch  - For Men',
#   'Only Kidz 20600 Digital Watch  - For Boys, Girls',
#   'Times 265TMS265 Party-Wedding Analog Watch  - For Men',
#   'Nexus NX_7703 Analog Watch  - For Women',
#   'Flippd FDLWBR3714 Fashion Analog Watch  - For Men',
#   'Lamex 3326 S Black And Black Analog Watch  - For Women',
#   'Sonata 8097YM01 Analog Watch  - For Women',
#   'Times 374TMS374 Party-Wedding Analog Watch  - For Women',
#   'Kool Kidz DMK-011-PK 01 Analog Watch  - For Boys, Girls',
#   'Timewel N911_1 Analog Watch  - For Women',
#   'Noise NOSWW025 Round Dial Jelly Analog Watch  - For Men, Women',
#   'Nexus NX_7570 Analog Watch  - For Women',
#   'Gift Island SW13676B Fashionin Digital Watch  - For Men',
#   'Sonata 7945SM01 Watch',
#   'Klaus Kobec CS04 Analog Watch  - For Women',
#   'Petrol RPWF01 Analog Watch  - For Men',
#   'Maxima 29182CMGI Attivo Analog Watch  - For Men',
#   'Petrol PCBBL67 Analog Watch  - For Men',
#   'Maxima 20250BMLI Swarovski Analog Watch  - For Women',
#   'Gift Island SW13389D Fashionin Digital Watch  - For Men',
#   'Maxima 10620PMLI Attivo Analog Watch  - For Women',
#   'Fastrack ND3062PP08 Tees Analog Watch  - For Men, Women',
#   'Maxima 19431CMGY Gold Analog Watch  - For Men',
#   'Sir Time ST01-SYBK Digital Watch  - For Men',
#   'Maxima 01727LPLN Mac Gold Analog Watch  - For Women',
#   'HMT 41045 Analog Watch  - For Men',
#   'Kool Kidz DMK-001-PR 01 Analog Watch  - For Boys, Girls',
#   'Timewel 1100-N145 Analog Watch  - For Men',
#   'HMT G5141 Watch  - For Men',
#   'Maxima 25052CMGY Analog Watch  - For Men',
#   'Maxima 27280PPGW Fiber Analog Watch  - For Men',
#   'HMT S3648 Analog Watch  - For Men',
#   'Sonata 7016YM07 Watch',
#   'Times 149B0149 Party-Wedding Analog Watch  - For Women',
#   'Timewel 1100-N1662_W Analog Watch  - For Women',
#   'Nexus NX_7591 Analog Watch  - For Women',
#   'Only Kidz 20368 Digital Watch  - For Boys, Girls',
#   'Sonata 8098YM01 Analog Watch  - For Women',
#   'Timewel 1100-N2017 Analog Watch  - For Women',
#   'Olvin 1697 SM05 Analog Watch  - For Women',
#   'Maxima 29234LMLI Attivo Analog Watch  - For Women',
#   'Noise NOSWW026 Round Dial Jelly Analog Watch  - For Men, Women',
#   'Gift Island SW13676E Fashionin Digital Watch  - For Men',
#   'Fastrack 3062PP09 Tees Pop Analog Watch  - For Men, Women',
#   'Fastrack 9912PP15 Tees Analog Watch  - For Men, Women',
#   'Times 314TMS314 Party-Wedding Analog Watch  - For Men',
#   'Times 325TMS325 Party-Wedding Analog Watch  - For Women',
#   'Sonata 8974PP01 Analog Watch  - For Women',
#   'Timewel 1100-N1192 Analog Watch  - For Men',
#   'Sonata 2160yl03 Analog Watch  - For Women',
#   'Sonata 8943YL03 Yuva Gold Analog Watch  - For Women',
#   'Sonata 8925YM06J Analog Watch  - For Women',
#   'Sonata 7089SL01 Yuva Analog Watch  - For Men',
#   'Sonata 7007SL02 Analog Watch  - For Men',
#   'Timewel 1100-N1639 Analog Watch  - For Women',
#   'HMT Sonata Gold Plated Watch For Men Sonata Analog Watch  - For Men',
#   'Lamex Timewear 3326-Black-Bk-1 Analog Watch  - For Women',
#   'Global Nomad GNLWBR0114 Analog Watch  - For Men',
#   'Kool Kidz DMK-007-BL 01 Analog Watch  - For Boys, Girls',
#   'Times SD_147 Casual Analog Watch  - For Women',
#   'Maxima 29080LMGI Attivo Analog Watch  - For Men',
#   'Times 283TMS283 Party-Wedding Analog Watch  - For Women',
#   'Noise NOSWW030 I M Famous Analog Watch  - For Men, Women',
#   'SVM Diamond321 New Analog Watch  - For Girls',
#   'Gift Island AST781 Analog Watch  - For Women',
#   'Maxima 06896LMGY Gold Analog Watch  - For Men',
#   'Times 101B0101 Sports Analog Watch  - For Boys',
#   'Fastrack 9297PP01 Sports Analog Watch  - For Men',
#   'Fastrack 9913PP03 Tees Analog Watch  - For Women',
#   'Sonata 8076YL01 Analog Watch  - For Women',
#   'Timewel N1792W Analog Watch  - For Men',
#   'Petrol PMW93B4 Analog Watch  - For Men',
#   'Hourglass HG 006 Analog Watch  - For Men',
#   'Maxima 19413PPSN FIBER COLLECTION Digital Watch  - For Men',
#   'Fluid FS201-BL01 Analog-Digital Watch  - For Women',
#   'Sonata Everyday Analog Watch - For Women',
#   'Timewel N1584 Analog Watch  - For Men',
#   'Nexus NX_7557 Analog Watch  - For Women',
#   'Flippd FDDC03 Analog Watch  - For Men',
#   'Maxima 07035LMLI Attivo Analog Watch  - For Women',
#   'Gift Island SW13388E Fashionin Digital Watch  - For Men',
#   'Fastrack 9912PP18 Tees Analog Watch  - For Men, Women',
#   'Timewel 1100-N1949_S Analog Watch  - For Women',
#   'Fastrack 9331PP01 Basics Analog Watch  - For Men',
#   'Maxima 29081LMGI Attivo Analog Watch  - For Men',
#   'Only Kidz 20233 Hannah Montana Analog Watch  - For Boys, Girls',
#   'SVM Diamond163 Fashion Analog Watch  - For Girls',
#   'Gift Island SW13392F Fashionin Digital Watch  - For Women',
#   'Noise NOSWW002 Analog Watch  - For Men, Women',
#   'Timewel N835_1 Analog Watch  - For Women',
#   'Now B170-SLL09 Now Analog Watch  - For Girls',
#   'Maxima 07602PPGW Aqua Analog Watch  - For Men',
#   'Sonata 8097YM03 Analog Watch  - For Women',
#   'Maxima 19883BMLI Swarovski Analog Watch  - For Women',
#   'HMT B022 HQ Analog Watch  - For Women',
#   'Gift Island SW13392C Fashionin Digital Watch  - For Women',
#   'Sonata 8925YM06 Analog Watch  - For Women',
#   'Timewel N1421W_1 Analog Watch  - For Men',
#   'Flippd FD15102 Analog Watch  - For Men',
#   'Kool Kidz DMK-011-BK 01 Analog Watch  - For Girls, Boys',
#   'Times 326TMS326 Party-Wedding Analog Watch  - For Women',
#   'Gift Island AST611 Analog Watch  - For Women',
#   'Like Steel Gold HBG Analog Watch  - For Girls, Women',
#   'Fluid FU203-OR01 Analog-Digital Watch  - For Men',
#   'Timewel 1100-N801 Analog Watch  - For Men',
#   'Neo Classic NC11-5004_G Analog Watch  - For Women',
#   'Now Q710-SOS07 NOW Analog Watch  - For Girls',
#   'Noise NOSWW013 Grip On Analog Watch  - For Women, Men',
#   'HMT OLSS 01 Analog Watch  - For Women',
#   'Times 327TMS327 Party-Wedding Analog Watch  - For Women',
#   'Fastrack 9792PP02 Basics Analog Watch  - For Women',
#   'Gift Island AST906 Analog Watch  - For Women',
#   'Flippd FDRBB2114 Fibre Analog Watch  - For Men',
#   'Forex 5501LT01 Casual Analog Watch  - For Men',
#   'Noise NOSWW014 Grip On Analog Watch  - For Men, Women',
#   'Logues LGSWATCH3136SL Analog Watch  - For Women',
#   'Sonata 8082SL01 Analog Watch  - For Women',
#   'Global Nomad GNLBBL15F3 Analog Watch  - For Men',
#   'Gift Island SW13390E Fashionin Digital Watch  - For Men',
#   'Maxima 29126LMGY Gold Analog Watch  - For Men',
#   'Timewel N1794B Analog Watch  - For Men',
#   'Neo Classic NC11-5004_W Analog Watch  - For Women',
#   'Sonata 7926SL01 Watch',
#   'Nexus NX_7690 Analog Watch  - For Women',
#   'Maxima 08587BMLY Gold Analog Watch  - For Women',
#   'Sonata super fiber Digital Watch  - For Boys, Men, Girls',
#   'Maxima 19884LMLI Swarovski Analog Watch  - For Women',
#   'Maxima 05712LMLY Analog Watch  - For Women',
#   'Gift Island SW13391B Fashionin Digital Watch  - For Men',
#   'Fastrack 9827PP10 Analog Watch  - For Women',
#   'Sonata 8076YL02 Analog Watch  - For Women',
#   'Sonata 87009SM01 Watch',
#   'Maxima 05711LMLY Gold Analog Watch  - For Women',
#   'HMT OLSS 03 Analog Watch  - For Women',
#   'Timewel 1100-N1949_B Analog Watch  - For Women',
#   'Fastrack 3062PP12 Tees Pop Analog Watch  - For Women, Men',
#   'Timewel 1100-N31 Analog Watch  - For Men',
#   'Timewel N1754_1 Analog Watch  - For Men',
#   'Fastrack 3062PP19 Tees Analog Watch  - For Men, Women',
#   'Maxima 20364CPGI Attivo Analog Watch  - For Men',
#   'Maxima 25014LMGI Attivo Analog Watch  - For Men',
#   'Sonata 7085YL01 Analog Watch  - For Men',
#   'Sonata 7078SL02 Watch',
#   'Times TIMES_98 Formal Analog Watch  - For Women, Girls',
#   'Timewel 1100-N1073G_1 Analog Watch  - For Men',
#   'Lamex Timewear 3326-Black-White-1 Analog-Digital Watch  - For Women',
#   'Flippd FD040149 Casual Analog Watch  - For Women, Girls',
#   'Flippd FD040107 Casual Analog Watch  - For Men, Boys',
#   'Fastrack ND9912PP04J Analog Watch  - For Women, Men',
#   'Flippd FDRBB2814(orange) Fibre Analog Watch  - For Men',
#   'Timewel 1100-N1944_B Analog Watch  - For Women',
#   'Fastrack 9912PP09 Tees Analog Watch  - For Men, Women',
#   'Flippd FDRBB1614 Fibre Analog Watch  - For Men',
#   'Times 123B0123 Sports Analog Watch  - For Boys',
#   'Timewel 1100-N1508 Analog Watch  - For Women',
#   'Maxima 07138CMGY Analog Watch  - For Men',
#   'SF by Sonata 7963PP02 Dean Analog Watch  - For Men',
#   'Flippd FDDC04 Analog Watch  - For Men',
#   'Sonata 8024SL10 Yuva Analog Watch  - For Women',
#   'Maxima 22020CMLY Analog Watch  - For Women',
#   'Now Q710-SLS09 NOW Analog Watch  - For Girls',
#   'Maxima 07034LMLI Attivo Analog Watch  - For Women',
#   'Timewel N1536(GW)_1 Analog Watch  - For Men',
#   'Curren Nx Blue Dial Stiched Strap Analog Watch  - For Men, Boys',
#   'Minuut MNT-017-SPT-BLU Analog Watch  - For Men',
#   'Romex Ultimate Urban Analog Watch  - For Boys, Men',
#   'Ridas 1825_black Sports Analog Watch  - For Men',
#   'Relish R456 Analog Watch  - For Men',
#   'Rich Club RC-2166WHT Solitaire Analog Watch  - For Girls, Women',
#   'Quartz 15265662 Smart Watch Strap',
#   'Britex BT9026 Bluetec Bucherer Analog Watch  - For Boys, Men',
#   'Fogg Fashion Store 3003-PK Modish Analog Watch  - For Women',
#   'Luba HH41 Stylo Analog Watch  - For Women',
#   'Luba DE45 Stylo Analog Watch  - For Women',
#   'Ridas 923_red Luxy Analog Watch  - For Women, Girls',
#   'SVM Navratri Special 7 Analog Watch  - For Girls, Women',
#   'Fighter FIGH_008 Digital Watch  - For Couple',
#   'Swiss Trend Artshai1630 Premium Analog Watch  - For Men',
#   'Geneva GEN-05 Crystal Studded Analog Watch  - For Women',
#   'Yepme 72596 Caitlin - Orange Analog Watch  - For Women',
#   'Luba ghk54 Stylo Analog Watch  - For Women',
#   'Follow Me SH1021 Ladies Leather Analog Watch  - For Women',
#   'Perucci PC-3333Purple Analog Watch  - For Women',
#   'Luba rk526 Rked Analog Watch  - For Women',
#   'Perucci PC-3333Yellow Analog Watch  - For Women',
#   'Perucci PC-301 Analog Watch  - For Men',
#   'Perucci PC-303 Analog Watch  - For Men',
#   'Perucci PC-310 Analog Watch  - For Men',
#   'Perucci PC-312 Analog Watch  - For Men',
#   'Chappin & Nellson CNL-50-White-RG Analog Watch  - For Women',
#   'Chappin & Nellson CNL-50-White Analog Watch  - For Women',
#   'Q&Q DA37J504Y Analog Watch  - For Women',
#   'Zoya-JQ ZJQ-CMBN-03 Solid Color Analog Watch  - For Girls, Women',
#   'HPD Butterfly Combo Bracelet Look Analog Watch  - For Girls, Women',
#   'Gesture 8062-WH Stylo Analog Watch  - For Women',
#   'Xemex ST1025SL07 New Generation Analog Watch  - For Women',
#   'Luba j52 Stylo Analog Watch  - For Women',
#   'Timebre TMLXPRL53 Premium Analog Watch  - For Women',
#   'RRTC RRTC1105SM00 Basic Analog Watch  - For Women',
#   'Perucci PC-502C Decker Analog Watch  - For Men',
#   'Perucci PCC-501C Decker Analog Watch  - For Men',
#   'Perucci PC-222 Decker Analog Watch  - For Men',
#   'Perucci Pc-126 & Pc-257 Decker Analog Watch  - For Men',
#   'Perucci Pc-122 & Pc-126 Decker Analog Watch  - For Men',
#   'Perucci PC-702W Decker Analog Watch  - For Men',
#   'Perucci Pc-257-2ps Decker Analog Watch  - For Men',
#   'Perucci PCC-502C Decker Analog Watch  - For Men',
#   'Perucci PC-501C & PC-219 Decker Analog Watch  - For Men',
#   'Perucci PC-122 Decker Analog Watch  - For Men',
#   'Perucci PC-218 Decker Analog Watch  - For Men',
#   'Perucci PC-501B & PC-226 Decker Analog Watch  - For Men',
#   'Perucci PC-414W Decker Analog Watch  - For Men',
#   'Perucci PC-4444 Decker Analog Watch  - For Women',
#   'LUBA bh23 Stylo Analog Watch  - For Men',
#   'Luba num8 Ring Analog Watch  - For Men',
#   'LUBA g58 Stylo Analog Watch  - For Men',
#   'LUBA ty47 Stylo Analog Watch  - For Men',
#   'LUBA rt23 Stylo Analog Watch  - For Men',
#   'Luba qw12 Stylo Analog Watch  - For Men',
#   "Scheffer's SC-B-S-8003 Analog Watch  - For Men",
#   'LUBA HF45 Stylo Analog Watch  - For Men',
#   'Luba JH854 Design Analog Watch  - For Men',
#   'Luba HD142 Antq Analog Watch  - For Men',
#   "Scheffer's SC-B-S-8004 Analog Watch  - For Men",
#   'Luba er23 Stylo Analog Watch  - For Men',
#   "Scheffer's SC-W-S-8004 Analog Watch  - For Men",
#   'Swisstyle SS-GR1409-BLK-CH Flunky Analog Watch  - For Men',
#   "Scheffer's SC-B-S-2862 Simple Analog Watch  - For Men",
#   'Luba SD453 Stylo Analog Watch  - For Women',
#   'Rana Watches Bw-Prsmd Barbie Analog Watch  - For Girls',
#   'R.S D&G16 Analog Watch  - For Men',
#   'Firstrace 101-107 Analog Watch  - For Couple',
#   'CB Fashion 118-125 Analog Watch  - For Couple',
#   'CB Fashion 115-122 Analog Watch  - For Women',
#   'CB Fashion 127-130 Analog Watch  - For Women',
#   'CB Fashion 108-121 Analog Watch  - For Women',
#   'Timex TI000I70600 Analog Watch  - For Men',
#   'Titan 1641YM01 Karishma Analog Watch  - For Men',
#   'Playboy BPB-1002-C Analog Watch  - For Women',
#   'Fimex fx167 Analog Watch  - For Girls',
#   'FNB Fnb-0125 Analog Watch  - For Women',
#   'V-Luma W600 Fashion Analog Watch  - For Men'],
#  ['Puma evoSPEED HPI Willow Cricket  Bat',
#   'Metro Sports Leather Cricket Ball -   Size: 5,  Diameter: 23 cm',
#   'SG VS 319 Plus Kashmir Willow Cricket  Bat',
#   'SG RSD Plus Kashmir Willow Cricket  Bat',
#   'AVM Splash 20-20 Kashmir Willow Cricket Bat',
#   'SS Ton Professional English Willow Cricket  Bat',
#   'SS Ton Heritage English Willow Cricket  Bat',
#   'GM Purist 909 English Willow Cricket  Bat',
#   'CW Legend Tennis Kashmir Willow Cricket  Bat',
#   'SM Bravo Kashmir Willow Cricket  Bat',
#   'Spick Cricket Shoes',
#   'SS League Special Cricket Ball',
#   'SM Sway Cricket Ball -   Size: 5,  Diameter: 2.5 cm',
#   'Sun Sports Hanging Ball Club Cricket Ball -   Size: 5,  Diameter: 2.5 cm',
#   'SG Prosoft Cricket Ball',
#   'APG Diamond Cricket Ball -   Size: 5,  Diameter: 2.5 cm',
#   'Stanford League Special Cricket Ball -   Size: 5.1\\2,  Diameter: 1.5 cm',
#   'THREE WICKETS Tricolor Kashmir Willow Cricket  Bat']]

# %% [markdown]
# This is the final recommendation.
#
# You can see the user's names followed by a list of recommendations based on their interests.
#
# Keep in mind that for the most part the recommendations are accurate, but you may chance upon some outliers, due to the random nature of product selection.

# %%
recommendations = get_actual_rec(rec_1)
print_rec()
# Out:
# Recommendations are:
#
# Rahul -> ['Amazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,\r\nAmazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,', 'Shortkut enterprises Model no 483 Mobile/Tablet Speaker', 'Amazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,\r\nAmazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,', 'Shortkut enterprises Model no 460 Mobile/Tablet Speaker', 'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Blue Kid-Proof Case']
#
# Gokul -> ['Shortkut enterprises Model no 460 Mobile/Tablet Speaker', 'stylishvilla Embroidered Kurta & Churidar', "FreeHand Solid Men's Straight Kurta", "I-Voc Men's Printed Casual Shirt", 'HMT OLSS 01 Analog Watch  - For Women', 'SM Sway Cricket Ball -   Size: 5,  Diameter: 2.5 cm']
#
# Ankita -> ["FreeHand Solid Men's Straight Kurta", "Jaipurkurti Striped Women's Straight Kurta", 'JDK NOVELTY Brocade, Art Silk, Organza Floral Print Multi-purpose Fabric, Kurti Fabric, Blouse Material, Dress/Top Material, Jacket Fabric, Salwar Suit Material, Kurta & Pallazo Material, Lehenga Choli Material, Lace, Kurta Fabric, Kurta & Patiyala Material, Kurta & Churidar Material, Sherwani Fabric', "FS Mini Klub Solid Baby Boy's Pathani Kurta", 'stylishvilla Embroidered Kurta & Churidar']
#
# Badrinath -> ["Kumi Women's Solid Casual, Festive, Party Shirt", "Nod'R Solid Men's V-neck T-Shirt", "Species Women's Floral Print Casual Shirt", "Wermin Solid Men's Round Neck T-Shirt", "I-Voc Men's Printed Casual Shirt"]
#
# Vijay -> ['Maxima 10620PMLI Attivo Analog Watch  - For Women', 'HMT OLSS 01 Analog Watch  - For Women', 'Maxima 04621CMLY Analog Watch  - For Women', 'Timewel 1100-N498 Analog Watch  - For Men', 'Sonata Everyday Analog Watch - For Men']
#
# Srikanth -> ['GM Purist 909 English Willow Cricket  Bat', 'SM Sway Cricket Ball -   Size: 5,  Diameter: 2.5 cm', 'CW Legend Tennis Kashmir Willow Cricket  Bat', 'Spick Cricket Shoes', 'Sun Sports Hanging Ball Club Cricket Ball -   Size: 5,  Diameter: 2.5 cm']

# %% [markdown]
# **You have reached the end of this notebook. Thank you for reading!**
